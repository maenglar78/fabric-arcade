# %% [markdown]
# # 🗺️ City Builder — Datapolis Dashboard
#
# Live KQL/Plotly dashboard of the Mayor's quest progress.
#
# **TODO (scaffold)** — implement panels:
# - 🏙️ **City map**: 8 district tiles, colored by status (locked / in-progress / built)
# - ⭐ **Mayor reputation** (cumulative from `CityEvents`)
# - 📈 **DAX measure scoreboard**: expected vs actual per district
# - 🔁 **Attempts per district** (DistrictAttempt vs DistrictBuilt)
# - 🏆 **Leaderboard** (Reputation by PlayerId)

# %%
# TODO: KQL connection + Plotly panels
# from azure.kusto.data import KustoClient
# import plotly.express as px
print("🚧 Scaffold — implement during development phase")
